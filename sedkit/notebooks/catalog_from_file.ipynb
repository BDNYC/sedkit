# %% [markdown]
# # Make a catalog of SEDs from a file of coordinates
# You can also create an SED Catalog by passing a file of `ra` and `dec` values (in decimal degrees) to the `SED.from_coord_list()` method like so:

# %%
# Imports
from sedkit import sed, spectrum, synphot, catalog
import astropy.units as q
import numpy as np
from pkg_resources import resource_filename
from bokeh.io import output_notebook, show
output_notebook()
# Out:
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# Make a new catalog
cat = catalog.Catalog()

# %%
# Read in the data
cat.from_file(resource_filename('sedkit', 'data/coords.txt'))
# Out:
# Setting age to (<Quantity 6. Gyr>, <Quantity 4. Gyr>)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-d9bc55659b7b> in <module>()
#       1 # Read in the data
# ----> 2 cat.from_file(resource_filename('sedkit', 'data/coords.txt'))
#
# /Users/jfilippazzo/Documents/Modules/SEDkit/sedkit/catalog.py in from_file(self, coords)
#     268             s.sky_coords = ra*q.deg, dec*q.deg
#     269             s.find_Gaia()
# --> 270             s.find_2MASS()
#     271             s.find_WISE()
#     272             s.make_sed()
#
# /Users/jfilippazzo/Documents/Modules/SEDkit/sedkit/sed.py in find_2MASS(self, **kwargs)
#     776                              ['Jmag', 'Hmag', 'Kmag'],
#     777                              ['2MASS.J', '2MASS.H', '2MASS.Ks'],
# --> 778                              **kwargs)
#     779
#     780     def find_Gaia(self, search_radius=15*q.arcsec, catalog='I/345/gaia2'):
#
# /Users/jfilippazzo/Documents/Modules/SEDkit/sedkit/sed.py in find_photometry(self, name, catalog, band_names, target_names, search_radius, idx, **kwargs)
#     868             for band, viz in zip(target_names, band_names):
#     869                 try:
# --> 870                     mag, unc = list(rec[[viz, 'e_'+viz]])
#     871                     mag, unc = round(float(mag), 3), round(float(unc), 3)
#     872                     self.add_photometry(band, mag, unc)
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/table/row.py in __getitem__(self, item)
#      43
#      44     def __getitem__(self, item):
# ---> 45         return self._table.columns[item][self._index]
#      46
#      47     def __setitem__(self, item, val):
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/table/table.py in __getitem__(self, item)
#     118         else:
#     119             raise IndexError('Illegal key or index value for {} object'
# --> 120                              .format(self.__class__.__name__))
#     121
#     122     def __setitem__(self, item, value):
#
# IndexError: Illegal key or index value for TableColumns object

# %%
# Check out the results
cat.results

# %%
# Plot some stuff
show(cat.plot('2MASS.J-2MASS.Ks', 'Teff'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-b24c7798e2df> in <module>()
#       1 # Plot some stuff
# ----> 2 show(cat.plot('2MASS.J-2MASS.Ks', 'Teff'))
#
# /Users/jfilippazzo/Documents/Modules/SEDkit/sedkit/catalog.py in plot(self, x, y, marker, color, scale, xlabel, ylabel, fig, **kwargs)
#     379
#     380         # Get the data
# --> 381         (xdata, xunit), (ydata, yunit) = self.get_data(x, y)
#     382
#     383         # Set axis labels
#
# /Users/jfilippazzo/Documents/Modules/SEDkit/sedkit/catalog.py in get_data(self, *args)
#     286             if '-' in x:
#     287                 x1, x2 = x.split('-')
# --> 288                 if self.results[x1].unit!=self.results[x2].unit:
#     289                     raise TypeError('Columns must be the same units.')
#     290
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1222     def __getitem__(self, item):
#    1223         if isinstance(item, six.string_types):
# -> 1224             return self.columns[item]
#    1225         elif isinstance(item, (int, np.integer)):
#    1226             return self.Row(self, item)
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/astropy/table/table.py in __getitem__(self, item)
#     107         """
#     108         if isinstance(item, six.string_types):
# --> 109             return OrderedDict.__getitem__(self, item)
#     110         elif isinstance(item, (int, np.integer)):
#     111             return self.values()[item]
#
# KeyError: '2MASS.J'
