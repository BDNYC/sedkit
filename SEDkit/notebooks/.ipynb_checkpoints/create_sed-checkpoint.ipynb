# %% [markdown]
# # Make an SED!
#
# ### Requirements
# - astropy-3.0.2
# - bokeh-0.12.6

# %%
# Imports
from SEDkit import sed, spectrum, synphot
import astropy.units as q
import numpy as np
from pkg_resources import resource_filename
from bokeh.io import output_notebook, show
output_notebook()
# Out:
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/pysynphot/locations.py:119: UserWarning: Extinction files should be moved to $PYSYN_CDBS/extinction for compatibility with future versions of pysynphot.
#   warnings.warn('Extinction files should be moved to '
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/pysynphot/locations.py:155: UserWarning: Extinction files not found in /grp/hst/cdbs/grid/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir,))
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/pysynphot/refs.py:114: UserWarning: No graph or component tables found; functionality will be SEVERELY crippled. No files found for /grp/hst/cdbs/mtab/*_tmg.fits.
#   'functionality will be SEVERELY crippled. ' + str(e))
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/pysynphot/refs.py:121: UserWarning: No thermal tables found, no thermal calculations can be performed. No files found for /grp/hst/cdbs/mtab/*_tmt.fits.
#   'no thermal calculations can be performed. ' + str(e))
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="428d526c-06a7-4c68-bd6f-8419ec3dfa27">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Let's create a new SED for an M-dwarf. The software assumes a field age if no `age` argument is given.

# %%
s = sed.SED(parallax=(1.7474*q.mas, 0.0501*q.mas), spectral_type='M0V', name='2MASS 261832886')
# Out:
# Make this handle asymmetric uncertainties!
# Setting age to (<Quantity 6.0 Gyr>, <Quantity 4.0 Gyr>)

# %% [markdown]
# Now let's add some photometry and take a look at how it's stored!

# %%
# You can pass an ascii file of photometry with the column names 
# 'band', 'magnitude', and 'uncertainty' like so...
s.add_photometry_file(resource_filename('SEDkit', 'data/M0V_photometry.txt'))

# Or you can add individual measurements like so...
s.add_photometry('Kepler.K', 16.332, 0.052)

# Take a look
print(s.photometry)
# Out:
#   band           eff         app_magnitude ...      abs_flux_unc      bandpass
#                   um                       ... erg / (Angstrom cm2 s)
# -------- ------------------- ------------- ... ---------------------- --------
#   SDSS.u 0.35565239687948447        20.486 ...                    0.0   SDSS.u
#   SDSS.g  0.4702495279331733        17.779 ...                    0.0   SDSS.g
#   SDSS.r  0.6175578881059804        16.431 ...                    0.0   SDSS.r
# Kepler.K  0.6303355872125808        16.332 ...                    0.0 Kepler.K
#   SDSS.i  0.7489976846298569        15.843 ...                    0.0   SDSS.i
#   SDSS.z   0.894670956505578        15.514 ...                    0.0   SDSS.z
#  2MASS.J  1.2393093155660664        14.391 ...                    0.0  2MASS.J
#  2MASS.H  1.6494947091246095        13.677 ...                    0.0  2MASS.H
# 2MASS.Ks   2.163860596453316        13.535 ...                    0.0 2MASS.Ks
#  WISE.W1  3.3897048577485647         13.55 ...                    0.0  WISE.W1
#  WISE.W2     4.6406356615375        13.581 ...                    0.0  WISE.W2
#  WISE.W3  12.567593607521216        12.884 ...                    0.0  WISE.W3

# %% [markdown]
# Spectra aren't necessary to build an SED but let's add some for fun.

# %%
# Add a spectrum from a file, specifying the astropy units
file = resource_filename('SEDkit', 'data/M0V_spectrum.txt')
s.add_spectrum_file(file, wave_units=q.um, flux_units=q.W/q.m**2/q.um)

# Alternatively, you can add the spectrum manually
"""
wave, flux, unc = np.genfromtxt(file, unpack=True)
s.add_spectrum(wave*q.um, flux*q.W/q.m**2/q.um, unc*q.W/q.m**2/q.um)
"""

# Take a look
show(s.spectra[0].plot)
# Out:
# Warning, 765 of 7119 bins contained negative fluxes; they have been set to zero.
# Looks like you already added this spectrum. If you want to overwrite, run drop_spectrum() first.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="95b3d7df-afe8-477f-b40e-bf452b20476e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("95b3d7df-afe8-477f-b40e-bf452b20476e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("95b3d7df-afe8-477f-b40e-bf452b20476e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '95b3d7df-afe8-477f-b40e-bf452b20476e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c8f8cdf5-954a-4189-8703-3873c054538c":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cd08ce32-67ed-4783-a31d-6fe925c902c7","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"65d3557a-7f20-4e78-afd0-02d3cc444629","type":"DataRange1d"},{"attributes":{"below":[{"id":"e6fa512a-9ba4-4686-a019-f932ee67629f","type":"LinearAxis"}],"left":[{"id":"fe9d4cdf-ccd9-4007-96ff-ff777b8ea2b8","type":"LinearAxis"}],"renderers":[{"id":"e6fa512a-9ba4-4686-a019-f932ee67629f","type":"LinearAxis"},{"id":"6ee63672-70d2-46bc-9d54-de71d23f0496","type":"Grid"},{"id":"fe9d4cdf-ccd9-4007-96ff-ff777b8ea2b8","type":"LinearAxis"},{"id":"117206fa-98f0-4797-8d55-33a238d61cd5","type":"Grid"},{"id":"cd08ce32-67ed-4783-a31d-6fe925c902c7","type":"BoxAnnotation"},{"id":"ee7e2e68-c79f-4464-8afc-f4deea667865","type":"GlyphRenderer"}],"title":{"id":"68363cf1-544a-4423-b7c2-afc91b2dcc80","type":"Title"},"tool_events":{"id":"c5199bea-deae-4d9d-a7c8-b00164dedc80","type":"ToolEvents"},"toolbar":{"id":"fbb2db1e-f0d4-40a8-bbca-4c88d6f4558f","type":"Toolbar"},"x_range":{"id":"58707eba-4328-4705-a0e1-6cad6766df8c","type":"DataRange1d"},"x_scale":{"id":"513528e5-c571-4be8-a8eb-d07a9e2a25ee","type":"LinearScale"},"y_range":{"id":"65d3557a-7f20-4e78-afd0-02d3cc444629","type":"DataRange1d"},"y_scale":{"id":"c0d96443-85d7-4dd3-bb4d-97655c4fca43","type":"LinearScale"}},"id":"b1a5b03b-3e07-4c36-96ea-c4e224a5fe0a","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"b1a5b03b-3e07-4c36-96ea-c4e224a5fe0a","subtype":"Figure","type":"Plot"}},"id":"30cb23b4-1fee-4faf-a0e3-380c1122290b","type":"HelpTool"},{"attributes":{"axis_label":"Flux Density [erg / (Angstrom cm2 s)]","formatter":{"id":"210f2145-2b9d-42a8-bd1e-cde088b429fb","type":"BasicTickFormatter"},"plot":{"id":"b1a5b03b-3e07-4c36-96ea-c4e224a5fe0a","subtype":"Figure","type":"Plot"},"ticker":{"id":"bc1e8cce-fa74-4952-8cc4-29143c206dcc","type":"BasicTicker"}},"id":"fe9d4cdf-ccd9-4007-96ff-ff777b8ea2b8","type":"LinearAxis"},{"attributes":{"callback":null},"id":"58707eba-4328-4705-a0e1-6cad6766df8c","type":"DataRange1d"},{"attributes":{"overlay":{"id":"cd08ce32-67ed-4783-a31d-6fe925c902c7","type":"BoxAnnotation"},"plot":{"id":"b1a5b03b-3e07-4c36-96ea-c4e224a5fe0a","subtype":"Figure","type":"Plot"}},"id":"008b781a-75ca-4922-9220-af93b54116c4","type":"BoxZoomTool"},{"attributes":{"axis_label":"Wavelength [um]","formatter":{"id":"b3b575a6-735a-493f-981e-c8b940e345a0","type":"BasicTickFormatter"},"plot":{"id":"b1a5b03b-3e07-4c36-96ea-c4e224a5fe0a","subtype":"Figure","type":"Plot"},"ticker":{"id":"0bb59c0d-449c-4e83-9174-7ae001ccffd4","type":"BasicTicker"}},"id":"e6fa512a-9ba4-4686-a019-f932ee67629f","type":"LinearAxis"},{"attributes":{"plot":{"id":"b1a5b03b-3e07-4c36-96ea-c4e224a5fe0a","subtype":"Figure","type":"Plot"}},"id":"ca5ed9aa-fc8d-405d-8665-f4af221bd44c","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"11448ea2-7efe-4c59-9bc8-395134329169","type":"Line"},{"attributes":{},"id":"c5199bea-deae-4d9d-a7c8-b00164dedc80","type":"ToolEvents"},{"attributes":{"plot":{"id":"b1a5b03b-3e07-4c36-96ea-c4e224a5fe0a","subtype":"Figure","type":"Plot"},"ticker":{"id":"0bb59c0d-449c-4e83-9174-7ae001ccffd4","type":"BasicTicker"}},"id":"6ee63672-70d2-46bc-9d54-de71d23f0496","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[7119]},"y":{"__ndarray__":"...","dtype":"float64","shape":[7119]}}},"id":"2bb73f63-42c0-4afa-a684-474ca472dce6","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":" ...

# %% [markdown]
# Now that our SED has all the data it needs, we can call the `results` method, which constructs the SED and caluclates the fundamental parameters.
#
# If no `radius` is given, one will be estimated from model isochrones using the calculated `Lbol` and assumed `age`.

# %%
print(s.results)
# Out:
# Setting radius to (<Quantity 0.5230620669828949 solRad>, <Quantity 0.42235463561880127 solRad>)
#     param           value                unc             units
# ------------- ------------------ ------------------- -------------
#          name    2MASS 261832886                  --            --
#           age                6.0                 4.0           Gyr
#      distance             572.28               16.41            pc
#      parallax             1.7474              0.0501           mas
#        radius 0.5230620669828949 0.42235463561880127        solRad
# spectral_type               60.0                 0.5            --
#    membership                 --                  --            --
#          fbol           1.02e-08             43800.0 erg / (cm2 s)
#          mbol                8.5   4.68191149656e+12            --
#          Lbol           3.98e+35            1.72e+48       erg / s
#      Lbol_sun              2.017   1872764598624.679            --
#          Mbol             -0.288     4680000000000.0            --
#          logg               4.28                0.29            --
#          mass 0.4473419499227051 0.44234942207904554       solMass
#          Teff              25488   27477337428143604             K

# %%
fig = s.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d6c495aea2b7> in <module>()
# ----> 1 fig = s.plot()
#
# /Users/jfilippazzo/Documents/Modules/SEDkit/SEDkit/sed.py in plot(self, app, photometry, spectra, integral, syn_photometry, blackbody, scale, output, **kwargs)
#     873         # Check for min and max spec data
#     874         try:
# --> 875             mn_xs, mx_xs = np.nanmin(spec_SED.wave), np.nanmax(spec_SED.wave)
#     876             mn_ys, mx_ys = np.nanmin(spec_SED.flux[spec_SED.flux>0]), np.nanmax(spec_SED.flux[spec_SED.flux>0])
#     877         except IOError:
#
# AttributeError: 'NoneType' object has no attribute 'wave'

# %% [markdown]
# But that radius seems wrong. Let's change it...

# %%
s.radius = 0.6*q.Rsun, 0.05*q.Rsun
# Out:
# Setting radius to (<Quantity 0.6 solRad>, <Quantity 0.05 solRad>)

# %%
print(s.results)
# Out:
#     param           value                unc             units
# ------------- ------------------ ------------------- -------------
#          name    2MASS 261832886                  --            --
#           age                6.0                 4.0           Gyr
#      distance             572.28               16.41            pc
#      parallax             1.7474              0.0501           mas
#        radius                0.6                0.05        solRad
# spectral_type               60.0                 0.5            --
#    membership                 --                  --            --
#          fbol           1.02e-08             43800.0 erg / (cm2 s)
#          mbol                8.5   4.68191149656e+12            --
#          Lbol           3.98e+35            1.72e+48       erg / s
#      Lbol_sun              2.017   1872764598624.679            --
#          Mbol             -0.288     4680000000000.0            --
#          logg               4.28                0.29            --
#          mass 0.4473419499227051 0.44234942207904554       solMass
#          Teff              23798   25655432992583236             K
