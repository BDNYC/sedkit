# %% [markdown]
# # Working with a `Spectrum`
# This notebook demonstrates some of the methods of the `Spectrum` class.

# %%
# Imports
from SEDkit import FileSpectrum, Spectrum
import astropy.units as q
from astropy.io import fits
from bokeh.io import output_notebook, show
from pkg_resources import resource_filename
import numpy as np
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a35ecd4f-057b-4e07-bf85-d0caace032ec">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Creating a `Spectrum`
# A spectrum can be created from a file spectrum...

# %%
# Add a spectrum from a file, specifying the astropy units
file = resource_filename('SEDkit', 'data/L3_spectrum.fits')
s = FileSpectrum(file, wave_units=q.um, flux_units=q.W/q.m**2/q.um)

# Plot it
s.plot(draw=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c0376dd0-81ea-4a22-96f7-bee5b502c611"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c0376dd0-81ea-4a22-96f7-bee5b502c611");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0376dd0-81ea-4a22-96f7-bee5b502c611");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0376dd0-81ea-4a22-96f7-bee5b502c611' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b44b8247-a814-4985-bac5-d8497e579277":{"roots":{"references":[{"attributes":{"plot":{"id":"d2893e75-5af9-40e0-a290-77748db2e08c","subtype":"Figure","type":"Plot"}},"id":"6ab8b5c5-ceab-479b-a706-7b84ca09b237","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"879ce30b-0ed4-44c7-87e9-1e8d52e42232","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"352bb85d-7ebd-4e06-8282-587307b17b99","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"513ba1b5-7b91-45e6-ac88-de4fbdab8013","type":"Patch"},{"attributes":{"dimension":1,"plot":{"id":"d2893e75-5af9-40e0-a290-77748db2e08c","subtype":"Figure","type":"Plot"},"ticker":{"id":"896505dd-755c-492c-80fb-905fe6aa7352","type":"BasicTicker"}},"id":"97a1584b-2aaf-43de-bd99-e77ae045ebd0","type":"Grid"},{"attributes":{"axis_label":"Wavelength [um]","formatter":{"id":"d9a4008c-0b70-4a49-a53b-c859db048a8b","type":"BasicTickFormatter"},"plot":{"id":"d2893e75-5af9-40e0-a290-77748db2e08c","subtype":"Figure","type":"Plot"},"ticker":{"id":"7f3b6eec-99d3-4687-8415-742e8910256b","type":"BasicTicker"}},"id":"b3b55360-64a1-4e09-b49c-8cb967fa92ae","type":"LinearAxis"},{"attributes":{"plot":{"id":"d2893e75-5af9-40e0-a290-77748db2e08c","subtype":"Figure","type":"Plot"}},"id":"debbfa38-a937-4b4d-99e2-bece8e219058","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"616125bc-f566-4be5-87d3-5e9817b4e568","type":"Patch"},{"attributes":{"plot":{"id":"d2893e75-5af9-40e0-a290-77748db2e08c","subtype":"Figure","type":"Plot"}},"id":"597af56d-0cdf-4771-ac88-427cb22b9ec3","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[11474]},"y":{"__ndarray__":"...","dtype":"float64","shape":[11474]}}},"id":"013e4c75-29e5-4f14-98f3-1b0386e70518","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"013e4c75-29e5-4f14-98f3-1b0386e70518","type":"ColumnDataSource"},"glyph":{"id":"513ba1b5-7b91-45e6-ac88-de4fbdab8013","type":"Patch"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"616125bc-f566-4be5-87d3-5e9817b4e568","type":"Patch"},"selection_glyph":null},"id":"ed08ef2f-4b69-4a01-8dc4-10446b846cbe","type":"GlyphRenderer"},{"attributes":{},"id":"d9a4008c-0b70-4a49-a53b-c859db048a8b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d2893e75-5af9-40e0-a290-77748db2e08c","subtype":"Figure","type":"Plot"}},"id":"5918bf96-b261-406f-809e-8fdcedcbaf2d","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"597af56d-0cdf-4771-ac88-427cb22b9ec3","type":"PanTool"},{"id":"e42ed5f5-4e17-4e88-be03-6d4828134511","type":"WheelZoomTool"},{"id":"765701eb-7389-4c35-ab06-42fb87048df6","type":"BoxZoomTool"},{"id":"debbfa38-a937-4b4d-99e2-bece8e219058","type":"SaveTool"},{"id":"6ab8b5c5-ceab-479b-a706-7b84ca09b237","type":"ResetTool"},{"id":"5918bf96-b261-406f-809e-8fdcedcbaf2d","type":"HelpTool"}]},"id":"9e8d14cd-c046-4256-bd23-263a388b81d4","type":"Toolbar"},{"attributes":{"data_source":{"id":"3868985f-a63d-4680-ae23-7ce3e84e54b2","type":"ColumnDataSource"},"glyph":{"id":"c600cb96-5951-4966-b8d4-79e33419912e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"352bb85d-7ebd-4e06-8282-587307b17b99","type":"Line"},"selection_glyph":null},"id":"35 ...

# %% [markdown]
# ...or `astropy.units.quantity.Quantity` arrays...

# %%
# Get the spectral data
wave, flux, unc = fits.getdata(file)
s = Spectrum(wave*q.um, flux*q.W/q.m**2/q.um, unc*q.W/q.m**2/q.um)

# Plot it
s.plot(draw=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="45b364b5-f28e-4f66-b184-c16f51480047"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("45b364b5-f28e-4f66-b184-c16f51480047");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("45b364b5-f28e-4f66-b184-c16f51480047");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '45b364b5-f28e-4f66-b184-c16f51480047' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a0c114db-f91d-401d-abdc-677724248f64":{"roots":{"references":[{"attributes":{},"id":"0fede399-2479-41c2-86b1-cddc9fd2f781","type":"LinearScale"},{"attributes":{},"id":"cce4e6f8-121a-499a-bd85-9f2fad0a34a0","type":"LinearScale"},{"attributes":{"plot":{"id":"2658f61f-7e47-465e-b7cd-cd665af7411f","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc270f51-0208-4789-ae1d-d052e74a0d6d","type":"BasicTicker"}},"id":"fa5171fd-286f-4d7a-95c7-d5297ff24b38","type":"Grid"},{"attributes":{"axis_label":"Wavelength [um]","formatter":{"id":"4dd26145-2dfe-453b-b597-80ce7eef518b","type":"BasicTickFormatter"},"plot":{"id":"2658f61f-7e47-465e-b7cd-cd665af7411f","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc270f51-0208-4789-ae1d-d052e74a0d6d","type":"BasicTicker"}},"id":"d35f9372-37e9-4a4e-872a-5c7e7985e78e","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#ff7f0e"},"line_alpha":{"value":0},"line_color":{"value":"#ff7f0e"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2944f0e1-2db6-4196-8abe-02777859da15","type":"Patch"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"23335612-3cb1-4a78-819d-c1a3c2a2447a","type":"Patch"},{"attributes":{"dimension":1,"plot":{"id":"2658f61f-7e47-465e-b7cd-cd665af7411f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4df8a4b1-5341-4595-a7c7-d958af0723e8","type":"BasicTicker"}},"id":"3f3c30a9-2244-41ee-8832-71c8701d5dd4","type":"Grid"},{"attributes":{"plot":{"id":"2658f61f-7e47-465e-b7cd-cd665af7411f","subtype":"Figure","type":"Plot"}},"id":"7520333e-d777-405b-bf9f-f6135ed76ee5","type":"WheelZoomTool"},{"attributes":{},"id":"cc05782d-56bd-499f-957f-326b982aba64","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"63ee9d58-0209-41ed-b6b9-887ffa76a503","type":"DataRange1d"},{"attributes":{"plot":{"id":"2658f61f-7e47-465e-b7cd-cd665af7411f","subtype":"Figure","type":"Plot"}},"id":"4e8d2ae9-5a78-408c-9ca0-4bf7c2874b52","type":"ResetTool"},{"attributes":{},"id":"4df8a4b1-5341-4595-a7c7-d958af0723e8","type":"BasicTicker"},{"attributes":{},"id":"fc270f51-0208-4789-ae1d-d052e74a0d6d","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"0efb2712-888f-4f51-a6e3-c55340014128","type":"Title"},{"attributes":{"callback":null},"id":"0bc7f220-0070-486b-b12a-ea30a907acd4","type":"DataRange1d"},{"attributes":{"plot":{"id":"2658f61f-7e47-465e-b7cd-cd665af7411f","subtype":"Figure","type":"Plot"}},"id":"0d6c041e-b8d6-4063-a529-742718fe1cf5","type":"HelpTool"},{"attributes":{"data_source":{"id":"cc8b25db-b5c4-430e-8ac6-76c40e78e69c","type":"ColumnDataSource"},"glyph":{"id":"c6d97a3d-8e8a-473e-bb40-19f8d5f7948d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0ad7e8f1-3ddb-4240-81f7-526c9ab13a37","type":"Line"},"selection_glyph":null},"id":"ab5c92df-0147-4116-9486-56f0849f40b7","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0ad7e8f1-3ddb-4240-81f7-526c9ab13a37","type":"Line"},{"attributes":{"overlay":{"id":"a46f5924-8a43-4e4a-84b4-29d9e75487e1","type":"BoxAnnotation"},"plot":{"id":"2658f61f-7e47-465e-b7cd-cd665af7411f","subtype":"Figure","type":"Plot"}},"id":"53f9d421-a101-4990-addc-b68c045d5ba8","type":"BoxZoomTool"},{"attributes":{},"id":"4dd26145-2dfe-453b-b597-80ce7eef518b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2658f61f-7e47-465e-b7cd-cd665af7411f","subtype":"Figure","type":"Plot"}},"id":"62e5bb7b-12b6-44b3-8532-d6e9a9fdd0ca","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[11474]},"y":{"__ndarray__":"...","dtype":"float64","shape":[11474]}}},"id":"37881a49-ea4c-4ce9-9b5a-2a82b1fdb4fd","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"2658f61f-7e47-465e-b7cd-cd665af7411f","sub ...

# %% [markdown]
# # Resampling
# Spectra can be resampled to a new resolution...

# %%
binned = s.resamp(resolution=100)
binned.plot(draw=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e3cee899-8086-4b39-af05-707457999168"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e3cee899-8086-4b39-af05-707457999168");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e3cee899-8086-4b39-af05-707457999168");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e3cee899-8086-4b39-af05-707457999168' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c059eb51-581a-4563-8dc6-9e29f99f3c4d":{"roots":{"references":[{"attributes":{"plot":{"id":"f4efa719-c5ff-489d-89ca-e942de7a0b77","subtype":"Figure","type":"Plot"}},"id":"1b0d276b-d17a-446e-b6d5-147de7ae6a98","type":"SaveTool"},{"attributes":{},"id":"e6c6ab09-eee8-4e7b-8188-af5bf34a9d00","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"d10150e0-1a80-4ce6-bac9-e7baacd0919b","type":"DataRange1d"},{"attributes":{},"id":"301ee4c6-ef02-4a84-a36e-168b54c50b19","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d03dd046-a1a7-4bc3-bf61-f6c73420598c","type":"Patch"},{"attributes":{"axis_label":"Flux Density [W / (m2 um)]","formatter":{"id":"6c8460b1-2d1c-437c-bf00-e67d508db2af","type":"BasicTickFormatter"},"plot":{"id":"f4efa719-c5ff-489d-89ca-e942de7a0b77","subtype":"Figure","type":"Plot"},"ticker":{"id":"a9664c65-be01-448e-96cb-dc0510e8c7c9","type":"BasicTicker"}},"id":"42cbe901-292a-41c6-a95d-d5143d6cf033","type":"LinearAxis"},{"attributes":{},"id":"c81022b8-9f34-4d47-9038-daffae983b9c","type":"LinearScale"},{"attributes":{"data_source":{"id":"20f2a497-1151-43ee-8c2c-2f92b63594df","type":"ColumnDataSource"},"glyph":{"id":"3b89ff87-985e-4509-b4c6-2e813677e00f","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"88e17268-8c59-46fb-b1d9-58543d1d5c44","type":"Line"},"selection_glyph":null},"id":"f4431fef-ade9-4215-91d2-4a78ec7e72ac","type":"GlyphRenderer"},{"attributes":{},"id":"7456fcd3-92f1-4d9d-b7b2-c109ab20706d","type":"LinearScale"},{"attributes":{"callback":null},"id":"c4ad1b1e-5d87-4f7d-9cce-d315b9309ce9","type":"DataRange1d"},{"attributes":{},"id":"a9664c65-be01-448e-96cb-dc0510e8c7c9","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3b89ff87-985e-4509-b4c6-2e813677e00f","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"88e17268-8c59-46fb-b1d9-58543d1d5c44","type":"Line"},{"attributes":{"plot":{"id":"f4efa719-c5ff-489d-89ca-e942de7a0b77","subtype":"Figure","type":"Plot"}},"id":"545f46cb-c5d3-41f0-adb8-e6b6d3734da0","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"47d6dc25-b8b9-414c-876c-04d293eca4a2","type":"BoxAnnotation"},"plot":{"id":"f4efa719-c5ff-489d-89ca-e942de7a0b77","subtype":"Figure","type":"Plot"}},"id":"9b190d94-e4d2-47de-87c5-59a2cb3603cf","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9a829d88-91a0-4cd6-8271-d8de60d99a78","type":"Patch"},{"attributes":{"plot":{"id":"f4efa719-c5ff-489d-89ca-e942de7a0b77","subtype":"Figure","type":"Plot"}},"id":"84a268f0-5cde-4ee4-b95b-63fed9213029","type":"ResetTool"},{"attributes":{"axis_label":"Wavelength [um]","formatter":{"id":"e6c6ab09-eee8-4e7b-8188-af5bf34a9d00","type":"BasicTickFormatter"},"plot":{"id":"f4efa719-c5ff-489d-89ca-e942de7a0b77","subtype":"Figure","type":"Plot"},"ticker":{"id":"301ee4c6-ef02-4a84-a36e-168b54c50b19","type":"BasicTicker"}},"id":"944ad49f-3075-4fe8-816b-22308cc23015","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[99]},"y":{"__ndarray__":"...","dtype":"float64","shape":[99]}}},"id":"20f2a497-1151-43ee-8c2c-2f92b63594df","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"f4efa719-c5ff-489d-89ca-e942de7a0b77","subtype":"Figure","type":"Plot"}},"id":"7da997b2-4e66-43de-b937-3f52006f214c","type":"PanTool"},{"attributes":{"plot":{"id":"f4efa719-c5ff-489d-89ca-e942de7a0b77","subtype":"Figure","type":"Plot"}},"id":"f468e6bb-6345-429f-9684-4a8eac72a085","type":"HelpTool"},{"attributes":{"plot":{"id":"f4efa719-c5ff-489d-89ca-e942de7a0b77","subtyp ...

# %% [markdown]
# ...or to a new wavelength array...

# %%
res = s.resamp(wave=np.linspace(1, 2, 200)*q.um)
res.plot(draw=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="717969df-469f-4057-8ee8-c7f3be0bf9bb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("717969df-469f-4057-8ee8-c7f3be0bf9bb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("717969df-469f-4057-8ee8-c7f3be0bf9bb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '717969df-469f-4057-8ee8-c7f3be0bf9bb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b7de94ea-f0a5-4f0f-8714-a92387fa551f":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"711c0f5e-34a0-4f84-9e46-50b5c9748555","type":"Patch"},{"attributes":{},"id":"5a68b550-bf38-427f-a0fd-18f73903e8dd","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"97451b8d-8cb6-499f-be46-bafaed9b7832","type":"ColumnDataSource"},"glyph":{"id":"05926d64-dc09-4fe9-af8a-c78925f3ec2e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3d78ad5e-1a8d-4e44-a3e3-e7552187e405","type":"Line"},"selection_glyph":null},"id":"d2f95a04-ebf1-4491-838f-5e4b04409afb","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"3329e9ef-4f45-4ae3-9d78-c5ee1237e697","type":"DataRange1d"},{"attributes":{"plot":{"id":"4abe06af-edeb-4623-a74f-e32975d6af82","subtype":"Figure","type":"Plot"}},"id":"6b77c014-13c7-416e-ac1e-9e40872a4b58","type":"SaveTool"},{"attributes":{"axis_label":"Flux Density [W / (m2 um)]","formatter":{"id":"73e2f726-a9bc-497d-9c78-7e6c0088362b","type":"BasicTickFormatter"},"plot":{"id":"4abe06af-edeb-4623-a74f-e32975d6af82","subtype":"Figure","type":"Plot"},"ticker":{"id":"caeee85f-0c8d-4fc5-8416-9e53ab875a04","type":"BasicTicker"}},"id":"fc4795a8-0d94-455a-bd27-0245c5910a3e","type":"LinearAxis"},{"attributes":{"plot":{"id":"4abe06af-edeb-4623-a74f-e32975d6af82","subtype":"Figure","type":"Plot"}},"id":"b37b1b58-4688-431c-8f07-a4bdbb2e7bd7","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7c4bdbbe-cbe0-43b5-be68-f247e166b142","type":"Patch"},{"attributes":{"callback":null},"id":"e52b3aee-22bc-415f-bb1d-e7454fdfaf25","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"92bb96f7-e937-4593-a4dd-1e68bf7cd039","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float32","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"97451b8d-8cb6-499f-be46-bafaed9b7832","type":"ColumnDataSource"},{"attributes":{},"id":"07c972d1-9c29-4719-ae18-14f121851992","type":"ToolEvents"},{"attributes":{},"id":"a17d61d5-9236-494b-8501-91c7318b7176","type":"BasicTicker"},{"attributes":{"axis_label":"Wavelength [um]","formatter":{"id":"5a68b550-bf38-427f-a0fd-18f73903e8dd","type":"BasicTickFormatter"},"plot":{"id":"4abe06af-edeb-4623-a74f-e32975d6af82","subtype":"Figure","type":"Plot"},"ticker":{"id":"a17d61d5-9236-494b-8501-91c7318b7176","type":"BasicTicker"}},"id":"a2458375-ec5d-4243-8d90-727a414cf2c0","type":"LinearAxis"},{"attributes":{"data_source":{"id":"4a852232-c7e6-4e1e-be93-b864fc03c367","type":"ColumnDataSource"},"glyph":{"id":"7c4bdbbe-cbe0-43b5-be68-f247e166b142","type":"Patch"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"711c0f5e-34a0-4f84-9e46-50b5c9748555","type":"Patch"},"selection_glyph":null},"id":"7eb2f7cf-58dd-48ec-82a3-67d9eed7e815","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"fbca11f0-c0b5-442b-ba9e-07202832517e","type":"BoxAnnotation"},"plot":{"id":"4abe06af-edeb-4623-a74f-e32975d6af82","subtype":"Figure","type":"Plot"}},"id":"149e6a6e-e935-461a-948e-47541329d51d","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"4abe06af-edeb-4623-a74f-e32975d6af82","subtype":"Figure","type":"Plot"}},"id":"7a180b4f-5706-45ad-a06d-c8a8e8f5445b","type":"ResetTool"},{"attributes":{},"id":"73e2f726-a9bc-497d-9c78-7e6c0088362b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4abe06af-edeb-4623-a74f-e32975d6af82","subtype":"Figure","type":"Plot"},"ticker":{"id":"a17d61d5-9236-494b-8501-91c7318b7176","type":"BasicTicker"}},"id":"db551643-6e14-475e-9a53-34f398b62123","type":"Grid"},{"attributes":{},"id":"caeee85f-0c8d-4fc5-8416-9e53ab875a04","type":"BasicTi ...

# %% [markdown]
# ## Make a composite `Spectrum`
# Spectra can be added together so that a new spectrum is returned, which takes the mean of the fluxes in overlapping wavelength regions.

# %%
# Make a Spectrum
file = resource_filename('SEDkit', 'data/L3_spectrum.fits')
s0 = FileSpectrum(file, wave_units=q.um, flux_units=q.W/q.m**2/q.um, name='Foobar')
s0.plot(draw=True)

# And another that looks different (downsampled, different wave units and values, randomized flux)
wave, flux, unc = s0.spectrum
wave += 2.01*q.um
wave = wave.to(q.AA)
flux = np.random.normal(flux, scale=np.max(unc))*flux.unit
s1 = Spectrum(wave[::4][50:-50], flux[::4][50:-50], unc[::4][50:-50])
s1.plot(draw=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f9efee038557> in <module>()
#       1 # Make a Spectrum
# ----> 2 file = resource_filename('SEDkit', 'data/L3_spectrum.fits')
#       3 s0 = FileSpectrum(file, wave_units=q.um, flux_units=q.W/q.m**2/q.um, name='Foobar')
#       4 s0.plot(draw=True)
#       5
#
# NameError: name 'resource_filename' is not defined

# %%
# Add them together
s2 = s0+s1
fig = s2.plot()
fig = s1.plot(fig)
show(s0.plot(fig))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9c3243a7baf7> in <module>()
#       1 # Add them together
# ----> 2 s2 = s0+s1
#       3 fig = s2.plot()
#       4 fig = s1.plot(fig)
#       5 show(s0.plot(fig))
#
# NameError: name 's0' is not defined

# %% [markdown]
# Good! The spectrum should be the mean flux in the overlapping wavelength regions.
